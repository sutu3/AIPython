# %%
path = '/kaggle/input/ithack/Jan_2024-Nov_2024.csv'

# %%
import pandas as pd
df = pd.read_csv(path)

# %%
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                              LIQUIDITY_POOL_ADDRESS  \
# 0      HLx5KbazmBafQfmjiYHWQaYqrXbDbJCAYLQci74sFVtR
# 1      4pJqcD8QmhLajJYn9muEtXJSz67H8FaKtzNknFubardo
# 2      5e6BdkPuafUJuWGiUm5zayGRTYNDy7WkDZzNfiFpuQts
# 3      65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg
# 4      65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg
# ...                                             ...
# 95428  GpqMSH1YM6oPmJ5xxEE2KfePf7uf5rXFbTW2TnxicRj6
# 95429  GpqMSH1YM6oPmJ5xxEE2KfePf7uf5rXFbTW2TnxicRj6
# 95430  AVs9TA4nWDzfPJE9gGVNJMVhcQy3V9PGazuz33BfG2RA
# 95431  AVs9TA4nWDzfPJE9gGVNJMVhcQy3V9PGazuz33BfG2RA
# 95432                                             ﻿
#
#                                                MINT  TOTAL_ADDED_LIQUIDITY  \
# 0      8KDsEUE3NdafcCVPqKrMrPfqh3oT4FzcxsYjwbMqpump           3.727000e+05
# 1      47uYAPNpAMJrLLxQZ7QQ9F1T6XBHqfPHLTfLsCCapump           3.584071e+06
# 2       uBR78nzmdk1W6wRxETznhW9jEuunn7ZTc9W3MGqpump           1.944022e+06
# 3      5p2zjqCd1WJzAVgcEnjhb9zWDU7b9XVhFhx4usiyN7jB           2.617475e+04
# 4      BxXmDhM8sTF3QG4foaVM2v1EUvg9DLSVUsDRTjR8tMyS           2.011766e+06
# ...                                             ...                    ...
# 95428  7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj           4.163527e+01
# 95429   USDH1SM1ojwWUga67PGrgFWUHibbjqMvuMaDkRJTgkX           5.010918e+03
# 95430  4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R           2.231211e+06
# 95431   So11111111111111111111111111111111111111112           2.644296e+04
# 95432                                           NaN                    NaN
#
#        TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 0                 6.930945e+04                 2.0                    1.0
# 1                 1.895394e+06                 1.0                    1.0
# 2                 2.960122e+06                17.0                   12.0
# 3                 3.546890e+04                 3.0                    1.0
# 4                 5.417064e+03                 3.0                    1.0
# ...                        ...                 ...                    ...
# 95428             1.059945e+02            392380.0                  188.0
# 95429             1.060718e+04            392380.0                  188.0
# 95430             6.508533e+06             15009.0                10346.0
# 95431             7.588321e+04             15009.0                10346.0
# 95432                      NaN                 NaN                    NaN
#
#        ADD_TO_REMOVE_RATIO LAST_POOL_ACTIVITY_TIMESTAMP  \
# 0                 5.377333      2024-10-31 23:52:02.000
# 1                 1.890937      2024-10-31 23:32:37.000
# 2                 0.656737      2024-10-31 23:52:37.000
# 3                 0.737963      2024-10-31 23:16:28.000
# 4               371.375729      2024-10-31 23:16:28.000
# ...                    ...                          ...
# 95428             0.392806      2024-08-05 19:34:18.000
# 95429             0.472408      2024-08-05 19:34:18.000
# 95430             0.342813      2024-10-31 18:33:28.000
# 95431             0.348469      2024-10-31 18:33:28.000
# 95432                  NaN                          NaN
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP      LAST_SWAP_TIMESTAMP  \
# 0           2024-10-31 23:41:11.000  2024-10-31 23:59:38.000
# 1           2024-10-31 23:32:14.000  2024-10-31 23:59:52.000
# 2           2024-10-31 23:32:04.000  2024-10-31 23:59:56.000
# 3           2024-10-31 23:09:45.000  2024-10-31 23:57:39.000
# 4           2024-10-31 23:09:45.000  2024-10-31 23:56:38.000
# ...                             ...                      ...
# 95428       2024-01-01 00:00:07.000  2024-10-31 23:57:21.000
# 95429       2024-01-01 00:00:07.000  2024-10-31 23:50:20.000
# 95430       2024-01-01 00:00:02.000  2024-10-31 23:59:13.000
# 95431       2024-01-01 00:00:02.000  2024-11-01 00:00:00.000
# 95432                           NaN                      NaN
#
#                                          LAST_SWAP_TX_ID INACTIVITY_STATUS
# 0      3Uc1L6z3iR6x11WjSKR6QwQvDT87JV9tFXfYa7WPX8tek6...            Active
# 1      5keT61KU7SeBLgz4FJTY9QESTHyDvHGVJDmha1wKsMk5U5...            Active
# 2      34B7xqS6mcFyd71icighCHRTg2BW2NLPUUBxnfh71fbiWC...            Active
# 3      eADFKxhPWAaGNkA5St5i695315fCYkunBv1QeEJUL1kAfu...            Active
# 4      4L5DBSsSqjThXDodGiFGZd6RQUg9yQG79MSzbCSrcGkXMd...            Active
# ...                                                  ...               ...
# 95428  5LC8g3BCFvWEYFEmvmhoF3uvEyzJnKMpi76kLBYNXwoTot...            Active
# 95429  dfSuFu4VzyB499egHxcgN7RXALwgnLvYERnozdEedjsKoJ...            Active
# 95430  3SxFS8BVTXTQ62sX4g3PXZbVrUvj7zc9CvPbvDCCN7ZuSG...            Active
# 95431  58dWq6mucodktckyMxtjtyHaiPW7PdiKVgSCELMD3oQG4x...            Active
# 95432                                                NaN               NaN
#
# [95433 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['LIQUIDITY_POOL_ADDRESS', 'MINT', 'TOTAL_ADDED_LIQUIDITY',
#        'TOTAL_REMOVED_LIQUIDITY', 'NUM_LIQUIDITY_ADDS',
#        'NUM_LIQUIDITY_REMOVES', 'ADD_TO_REMOVE_RATIO',
#        'LAST_POOL_ACTIVITY_TIMESTAMP', 'FIRST_POOL_ACTIVITY_TIMESTAMP',
#        'LAST_SWAP_TIMESTAMP', 'LAST_SWAP_TX_ID', 'INACTIVITY_STATUS'],
#       dtype='object')

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS           0.000000
# MINT                             0.001048
# TOTAL_ADDED_LIQUIDITY            0.001048
# TOTAL_REMOVED_LIQUIDITY          0.001048
# NUM_LIQUIDITY_ADDS               0.001048
# NUM_LIQUIDITY_REMOVES            0.001048
# ADD_TO_REMOVE_RATIO              0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP     0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP    0.001048
# LAST_SWAP_TIMESTAMP              0.540693
# LAST_SWAP_TX_ID                  0.540693
# INACTIVITY_STATUS                0.001048
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape
# Out:
# (95433, 12)

# %%
df.head().to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {0: 'HLx5KbazmBafQfmjiYHWQaYqrXbDbJCAYLQci74sFVtR',
#   1: '4pJqcD8QmhLajJYn9muEtXJSz67H8FaKtzNknFubardo',
#   2: '5e6BdkPuafUJuWGiUm5zayGRTYNDy7WkDZzNfiFpuQts',
#   3: '65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg',
#   4: '65j8XPXjd5ZhoHPtWDY4kKZKbgjJQhALPisrWrgWDhBg'},
#  'MINT': {0: '8KDsEUE3NdafcCVPqKrMrPfqh3oT4FzcxsYjwbMqpump',
#   1: '47uYAPNpAMJrLLxQZ7QQ9F1T6XBHqfPHLTfLsCCapump',
#   2: 'uBR78nzmdk1W6wRxETznhW9jEuunn7ZTc9W3MGqpump',
#   3: '5p2zjqCd1WJzAVgcEnjhb9zWDU7b9XVhFhx4usiyN7jB',
#   4: 'BxXmDhM8sTF3QG4foaVM2v1EUvg9DLSVUsDRTjR8tMyS'},
#  'TOTAL_ADDED_LIQUIDITY': {0: 372699.999937,
#   1: 3584071.0,
#   2: 1944021.819549,
#   3: 26174.75462778,
#   4: 2011766.101511},
#  'TOTAL_REMOVED_LIQUIDITY': {0: 69309.446048,
#   1: 1895394.482757,
#   2: 2960122.351972,
#   3: 35468.90254633,
#   4: 5417.064025},
#  'NUM_LIQUIDITY_ADDS': {0: 2.0, 1: 1.0, 2: 17.0, 3: 3.0, 4: 3.0},
#  'NUM_LIQUIDITY_REMOVES': {0: 1.0, 1: 1.0, 2: 12.0, 3: 1.0, 4: 1.0},
#  'ADD_TO_REMOVE_RATIO': {0: 5.377333411,
#   1: 1.890936706,
#   2: 0.6567369819,
#   3: 0.7379634764,
#   4: 371.375729035},
#  'LAST_POOL_ACTIVITY_TIMESTAMP': {0: '2024-10-31 23:52:02.000',
#   1: '2024-10-31 23:32:37.000',
#   2: '2024-10-31 23:52:37.000',
#   3: '2024-10-31 23:16:28.000',
#   4: '2024-10-31 23:16:28.000'},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP': {0: '2024-10-31 23:41:11.000',
#   1: '2024-10-31 23:32:14.000',
#   2: '2024-10-31 23:32:04.000',
#   3: '2024-10-31 23:09:45.000',
#   4: '2024-10-31 23:09:45.000'},
#  'LAST_SWAP_TIMESTAMP': {0: '2024-10-31 23:59:38.000',
#   1: '2024-10-31 23:59:52.000',
#   2: '2024-10-31 23:59:56.000',
#   3: '2024-10-31 23:57:39.000',
#   4: '2024-10-31 23:56:38.000'},
#  'LAST_SWAP_TX_ID': {0: '3Uc1L6z3iR6x11WjSKR6QwQvDT87JV9tFXfYa7WPX8tek6oRoAaKS4fXZiFr8m4aS2ovrgmcAU2nc8fsBCYFsUo6',
#   1: '5keT61KU7SeBLgz4FJTY9QESTHyDvHGVJDmha1wKsMk5U5nzTsLfHZqCAFA47Q797RhXUanqdjWxyufi3pxtCkE1',
#   2: '34B7xqS6mcFyd71icighCHRTg2BW2NLPUUBxnfh71fbiWCWbMfRyrQ633QuVSk3BDYyZx3NPPzRmWyNneAvc5oNS',
#   3: 'eADFKxhPWAaGNkA5St5i695315fCYkunBv1QeEJUL1kAfuG2GF7EfVK8We6xm1PNCtRHexHoqfwEbqbkmjznkWK',
#   4: '4L5DBSsSqjThXDodGiFGZd6RQUg9yQG79MSzbCSrcGkXMdB6aR1yJLcqGPPf3b6qJpDKzbDLZZY1NsRMxYxSztbQ'},
#  'INACTIVITY_STATUS': {0: 'Active',
#   1: 'Active',
#   2: 'Active',
#   3: 'Active',
#   4: 'Active'}}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS         95433 non-null  object
#  1   MINT                           95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY          95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY        95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS             95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES          95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO            95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP   95432 non-null  object
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP  95432 non-null  object
#  9   LAST_SWAP_TIMESTAMP            94917 non-null  object
#  10  LAST_SWAP_TX_ID                94917 non-null  object
#  11  INACTIVITY_STATUS              95432 non-null  object
# dtypes: float64(5), object(7)
# memory usage: 8.7+ MB

# %%
timestamp_cols = [
    'LAST_POOL_ACTIVITY_TIMESTAMP',
    'FIRST_POOL_ACTIVITY_TIMESTAMP',
    'LAST_SWAP_TIMESTAMP'
]

for col in timestamp_cols:
    df[col] = df[col].str.split('.').str[0]
    df[col] = pd.to_datetime(df[col], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS         95433 non-null  object
#  1   MINT                           95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY          95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY        95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS             95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES          95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO            95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP   95432 non-null  datetime64[ns]
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP  95432 non-null  datetime64[ns]
#  9   LAST_SWAP_TIMESTAMP            94917 non-null  datetime64[ns]
#  10  LAST_SWAP_TX_ID                94917 non-null  object
#  11  INACTIVITY_STATUS              95432 non-null  object
# dtypes: datetime64[ns](3), float64(5), object(4)
# memory usage: 8.7+ MB

# %%
datetime_cols = df.select_dtypes(include=['datetime64[ns]']).columns.tolist()

for col in datetime_cols:
    df[f"{col}_ts"] = df[col].astype('int64') // 10**9  # Giây

# %%
for col in datetime_cols:
    df[f'{col}_hour'] = df[col].dt.hour
    df[f'{col}_day'] = df[col].dt.day
    df[f'{col}_weekday'] = df[col].dt.weekday  # Monday = 0, Sunday = 6
    df[f'{col}_month'] = df[col].dt.month

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.000000
# MINT                                     0.001048
# TOTAL_ADDED_LIQUIDITY                    0.001048
# TOTAL_REMOVED_LIQUIDITY                  0.001048
# NUM_LIQUIDITY_ADDS                       0.001048
# NUM_LIQUIDITY_REMOVES                    0.001048
# ADD_TO_REMOVE_RATIO                      0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP             0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP            0.001048
# LAST_SWAP_TIMESTAMP                      0.540693
# LAST_SWAP_TX_ID                          0.540693
# INACTIVITY_STATUS                        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.000000
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.000000
# LAST_SWAP_TIMESTAMP_ts                   0.000000
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.001048
# LAST_SWAP_TIMESTAMP_hour                 0.540693
# LAST_SWAP_TIMESTAMP_day                  0.540693
# LAST_SWAP_TIMESTAMP_weekday              0.540693
# LAST_SWAP_TIMESTAMP_month                0.540693
# dtype: float64

# %%
df.shape
# Out:
# (95433, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS                 95433 non-null  object
#  1   MINT                                   95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY                  95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY                95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS                     95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES                  95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO                    95432 non-null  float64
#  7   LAST_POOL_ACTIVITY_TIMESTAMP           95432 non-null  datetime64[ns]
#  8   FIRST_POOL_ACTIVITY_TIMESTAMP          95432 non-null  datetime64[ns]
#  9   LAST_SWAP_TIMESTAMP                    94917 non-null  datetime64[ns]
#  10  LAST_SWAP_TX_ID                        94917 non-null  object
#  11  INACTIVITY_STATUS                      95432 non-null  object
#  12  LAST_POOL_ACTIVITY_TIMESTAMP_ts        95433 non-null  int64
#  13  FIRST_POOL_ACTIVITY_TIMESTAMP_ts       95433 non-null  int64
#  14  LAST_SWAP_TIMESTAMP_ts                 95433 non-null  int64
#  15  LAST_POOL_ACTIVITY_TIMESTAMP_hour      95432 non-null  float64
#  16  LAST_POOL_ACTIVITY_TIMESTAMP_day       95432 non-null  float64
#  17  LAST_POOL_ACTIVITY_TIMESTAMP_weekday   95432 non-null  float64
#  18  LAST_POOL_ACTIVITY_TIMESTAMP_month     95432 non-null  float64
#  19  FIRST_POOL_ACTIVITY_TIMESTAMP_hour     95432 non-null  float64
#  20  FIRST_POOL_ACTIVITY_TIMESTAMP_day      95432 non-null  float64
#  21  FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  95432 non-null  float64
#  22  FIRST_POOL_ACTIVITY_TIMESTAMP_month    95432 non-null  float64
#  23  LAST_SWAP_TIMESTAMP_hour               94917 non-null  float64
#  24  LAST_SWAP_TIMESTAMP_day                94917 non-null  float64
#  25  LAST_SWAP_TIMESTAMP_weekday            94917 non-null  float64
#  26  LAST_SWAP_TIMESTAMP_month              94917 non-null  float64
# dtypes: datetime64[ns](3), float64(17), int64(3), object(4)
# memory usage: 19.7+ MB

# %%
df.drop(columns=datetime_cols, inplace=True)

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
numeric_cols
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month',
#  'LAST_SWAP_TIMESTAMP_hour',
#  'LAST_SWAP_TIMESTAMP_day',
#  'LAST_SWAP_TIMESTAMP_weekday',
#  'LAST_SWAP_TIMESTAMP_month']

# %%
categorical_cols
# Out:
# ['LIQUIDITY_POOL_ADDRESS', 'MINT', 'LAST_SWAP_TX_ID', 'INACTIVITY_STATUS']

# %%
for col in df.columns:
    print(f"{col}: {df[col].dtype}")
# Out:
# LIQUIDITY_POOL_ADDRESS: object
# MINT: object
# TOTAL_ADDED_LIQUIDITY: float64
# TOTAL_REMOVED_LIQUIDITY: float64
# NUM_LIQUIDITY_ADDS: float64
# NUM_LIQUIDITY_REMOVES: float64
# ADD_TO_REMOVE_RATIO: float64
# LAST_SWAP_TX_ID: object
# INACTIVITY_STATUS: object
# LAST_POOL_ACTIVITY_TIMESTAMP_ts: int64
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts: int64
# LAST_SWAP_TIMESTAMP_ts: int64
# LAST_POOL_ACTIVITY_TIMESTAMP_hour: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_day: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday: float64
# LAST_POOL_ACTIVITY_TIMESTAMP_month: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_day: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday: float64
# FIRST_POOL_ACTIVITY_TIMESTAMP_month: float64
# LAST_SWAP_TIMESTAMP_hour: float64
# LAST_SWAP_TIMESTAMP_day: float64
# LAST_SWAP_TIMESTAMP_weekday: float64
# LAST_SWAP_TIMESTAMP_month: float64

# %%
datetime_cols = df.select_dtypes(include=['datetime64[ns]']).columns.tolist()

for col in datetime_cols:
    df[f"{col}_ts"] = df[col].astype('int64') // 10**9  # Giây

# %%
for col in datetime_cols:
    df[f'{col}_hour'] = df[col].dt.hour
    df[f'{col}_day'] = df[col].dt.day
    df[f'{col}_weekday'] = df[col].dt.weekday  # Monday = 0, Sunday = 6
    df[f'{col}_month'] = df[col].dt.month

# %%
df.shape
# Out:
# (95433, 24)

# %%
df.drop(columns=datetime_cols, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95433 entries, 0 to 95432
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   LIQUIDITY_POOL_ADDRESS                 95433 non-null  object
#  1   MINT                                   95432 non-null  object
#  2   TOTAL_ADDED_LIQUIDITY                  95432 non-null  float64
#  3   TOTAL_REMOVED_LIQUIDITY                95432 non-null  float64
#  4   NUM_LIQUIDITY_ADDS                     95432 non-null  float64
#  5   NUM_LIQUIDITY_REMOVES                  95432 non-null  float64
#  6   ADD_TO_REMOVE_RATIO                    95432 non-null  float64
#  7   LAST_SWAP_TX_ID                        94917 non-null  object
#  8   INACTIVITY_STATUS                      95432 non-null  object
#  9   LAST_POOL_ACTIVITY_TIMESTAMP_ts        95433 non-null  int64
#  10  FIRST_POOL_ACTIVITY_TIMESTAMP_ts       95433 non-null  int64
#  11  LAST_SWAP_TIMESTAMP_ts                 95433 non-null  int64
#  12  LAST_POOL_ACTIVITY_TIMESTAMP_hour      95432 non-null  float64
#  13  LAST_POOL_ACTIVITY_TIMESTAMP_day       95432 non-null  float64
#  14  LAST_POOL_ACTIVITY_TIMESTAMP_weekday   95432 non-null  float64
#  15  LAST_POOL_ACTIVITY_TIMESTAMP_month     95432 non-null  float64
#  16  FIRST_POOL_ACTIVITY_TIMESTAMP_hour     95432 non-null  float64
#  17  FIRST_POOL_ACTIVITY_TIMESTAMP_day      95432 non-null  float64
#  18  FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  95432 non-null  float64
#  19  FIRST_POOL_ACTIVITY_TIMESTAMP_month    95432 non-null  float64
#  20  LAST_SWAP_TIMESTAMP_hour               94917 non-null  float64
#  21  LAST_SWAP_TIMESTAMP_day                94917 non-null  float64
#  22  LAST_SWAP_TIMESTAMP_weekday            94917 non-null  float64
#  23  LAST_SWAP_TIMESTAMP_month              94917 non-null  float64
# dtypes: float64(17), int64(3), object(4)
# memory usage: 17.5+ MB

# %%
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
numeric_cols
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts',
#  'LAST_SWAP_TIMESTAMP_ts',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month',
#  'LAST_SWAP_TIMESTAMP_hour',
#  'LAST_SWAP_TIMESTAMP_day',
#  'LAST_SWAP_TIMESTAMP_weekday',
#  'LAST_SWAP_TIMESTAMP_month']

# %%
time_cols = ['LAST_SWAP_TIMESTAMP_hour', 'LAST_SWAP_TIMESTAMP_day', 
             'LAST_SWAP_TIMESTAMP_weekday', 'LAST_SWAP_TIMESTAMP_month']

df[time_cols] = df[time_cols].fillna(-1)

# %%
df.isna().sum() / len(df) * 100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.000000
# MINT                                     0.001048
# TOTAL_ADDED_LIQUIDITY                    0.001048
# TOTAL_REMOVED_LIQUIDITY                  0.001048
# NUM_LIQUIDITY_ADDS                       0.001048
# NUM_LIQUIDITY_REMOVES                    0.001048
# ADD_TO_REMOVE_RATIO                      0.001048
# LAST_SWAP_TX_ID                          0.540693
# INACTIVITY_STATUS                        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.000000
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.000000
# LAST_SWAP_TIMESTAMP_ts                   0.000000
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.001048
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.001048
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.001048
# LAST_SWAP_TIMESTAMP_hour                 0.000000
# LAST_SWAP_TIMESTAMP_day                  0.000000
# LAST_SWAP_TIMESTAMP_weekday              0.000000
# LAST_SWAP_TIMESTAMP_month                0.000000
# dtype: float64

# %%
df = df.drop(columns=['LAST_SWAP_TX_ID'])

# %%
numeric_with_nan = [
    col for col in df.select_dtypes(include=['number']).columns 
    if df[col].isnull().any()
]
numeric_with_nan
# Out:
# ['TOTAL_ADDED_LIQUIDITY',
#  'TOTAL_REMOVED_LIQUIDITY',
#  'NUM_LIQUIDITY_ADDS',
#  'NUM_LIQUIDITY_REMOVES',
#  'ADD_TO_REMOVE_RATIO',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month']

# %%
# Plot histogram for each numeric column with NaNs
for col in numeric_with_nan:
    plt.figure(figsize=(6, 4))
    plt.hist(df[col].dropna(), bins=50)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
col_to_fill_0 = ['TOTAL_ADDED_LIQUIDITY',                    
'TOTAL_REMOVED_LIQUIDITY',                  
'NUM_LIQUIDITY_ADDS',                       
'NUM_LIQUIDITY_REMOVES',                    
'ADD_TO_REMOVE_RATIO']
df[col_to_fill_0] = df[col_to_fill_0].fillna(0)

# %%
df.dropna(subset=['MINT'], inplace=True)

# %%
# Danh sách 8 cột đặc trưng thời gian suy ra
time_derived_features_to_fill = [
    'LAST_POOL_ACTIVITY_TIMESTAMP_hour',
    'LAST_POOL_ACTIVITY_TIMESTAMP_day',
    'LAST_POOL_ACTIVITY_TIMESTAMP_weekday',
    'LAST_POOL_ACTIVITY_TIMESTAMP_month',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_hour',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_day',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_month'
]

for col in time_derived_features_to_fill:
    if col in df.columns:
        df[col].fillna(-1, inplace=True)

print("\nSố lượng NaN ở các cột thời gian suy ra sau khi điền:")
print(df[time_derived_features_to_fill].isnull().sum())
# Out:
# Số lượng NaN ở các cột thời gian suy ra sau khi điền:
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0
# dtype: int64
# /tmp/ipykernel_35/860428239.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(-1, inplace=True)

# %%
df.isna().sum()/len(df)*100
# Out:
# LIQUIDITY_POOL_ADDRESS                   0.0
# MINT                                     0.0
# TOTAL_ADDED_LIQUIDITY                    0.0
# TOTAL_REMOVED_LIQUIDITY                  0.0
# NUM_LIQUIDITY_ADDS                       0.0
# NUM_LIQUIDITY_REMOVES                    0.0
# ADD_TO_REMOVE_RATIO                      0.0
# INACTIVITY_STATUS                        0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_ts          0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_ts         0.0
# LAST_SWAP_TIMESTAMP_ts                   0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_hour        0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_day         0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_weekday     0.0
# LAST_POOL_ACTIVITY_TIMESTAMP_month       0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_hour       0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_day        0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_weekday    0.0
# FIRST_POOL_ACTIVITY_TIMESTAMP_month      0.0
# LAST_SWAP_TIMESTAMP_hour                 0.0
# LAST_SWAP_TIMESTAMP_day                  0.0
# LAST_SWAP_TIMESTAMP_weekday              0.0
# LAST_SWAP_TIMESTAMP_month                0.0
# dtype: float64

# %%
inactivity_status_one_hot = pd.get_dummies(df['INACTIVITY_STATUS'], prefix='INACTIVITY_STATUS')


df = pd.concat([df, inactivity_status_one_hot], axis=1)

df.drop('INACTIVITY_STATUS', axis=1, inplace=True)

# %%
estimated_contamination = 0.005

# %%
import optuna
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split 

def objective(trial, X_data):

    # Gợi ý các tham số cho Isolation Forest
    n_estimators = trial.suggest_int('n_estimators', 50, 300) # Số cây trong rừng
    max_samples = trial.suggest_int('max_samples', 100, min(2048, len(X_data))) # Số mẫu lấy để xây cây
    
    model = IsolationForest(n_estimators=n_estimators,
                            max_samples=max_samples,
                            contamination=estimated_contamination, # Sử dụng giá trị ước tính
                            random_state=trial.number) # Sử dụng trial.number để đa dạng hóa seed

    # Fit mô hình với toàn bộ tập dữ liệu đặc trưng
    model.fit(X_data)

    # Tính điểm bất thường
    anomaly_scores = model.decision_function(X_data)

    # Phân loại điểm thành "inliers" (điểm > 0) và "outliers" (điểm <= 0) dựa trên ngưỡng 0
    # (trước khi áp dụng ngưỡng contamination)
    inlier_scores = anomaly_scores[anomaly_scores > 0]
    outlier_scores = anomaly_scores[anomaly_scores <= 0]

    # Tính điểm trung vị cho từng nhóm
    # Xử lý trường hợp một trong hai nhóm rỗng
    median_inlier = np.median(inlier_scores) if len(inlier_scores) > 0 else 0
    median_outlier = np.median(outlier_scores) if len(outlier_scores) > 0 else 0

    # Hàm mục tiêu: Tối đa hóa sự khác biệt giữa trung vị inlier và trung vị outlier
    # Điểm bất thường càng âm càng tốt, nên median_outlier sẽ là một số âm.
    # median_inlier - median_outlier = median_inlier + abs(median_outlier) -> muốn giá trị này lớn
    objective_value = median_inlier - median_outlier

    # Optuna mặc định tìm cách minimize. Để tối đa hóa, ta trả về giá trị âm
    return -objective_value

# %%
columns_to_drop_for_X = [
    'LIQUIDITY_POOL_ADDRESS',
    'MINT', 
    'LAST_SWAP_TX_ID', 
    'LAST_POOL_ACTIVITY_TIMESTAMP_ts',
    'FIRST_POOL_ACTIVITY_TIMESTAMP_ts',
    'LAST_SWAP_TIMESTAMP_ts'
]
X = df.drop(columns=columns_to_drop_for_X, errors='ignore')

# %%
study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial, X), n_trials=100) 
# In ra kết quả tốt nhất
print("\nKết quả tối ưu hóa:")
print(f"Tham số tốt nhất: {study.best_params}")
print(f"Giá trị hàm mục tiêu tốt nhất (âm của sự khác biệt trung vị): {study.best_value}")
# Out:
# [I 2025-05-20 06:51:03,642] A new study created in memory with name: no-name-09e1bca4-1519-4c85-bc05-c8cf75a7a974
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:51:15,193] Trial 0 finished with value: -0.19182751475055676 and parameters: {'n_estimators': 183, 'max_samples': 842}. Best is trial 0 with value: -0.19182751475055676.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:51:27,603] Trial 1 finished with value: -0.20398252376278883 and parameters: {'n_estimators': 231, 'max_samples': 254}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:51:41,517] Trial 2 finished with value: -0.1939986390201591 and parameters: {'n_estimators': 212, 'max_samples': 1398}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:51:53,067] Trial 3 finished with value: -0.20332183731741504 and parameters: {'n_estimators': 186, 'max_samples': 668}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:52:03,924] Trial 4 finished with value: -0.2002339694167866 and parameters: {'n_estimators': 163, 'max_samples': 1325}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:52:18,217] Trial 5 finished with value: -0.1972949959810473 and parameters: {'n_estimators': 214, 'max_samples': 1156}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:52:35,300] Trial 6 finished with value: -0.19892124815948004 and parameters: {'n_estimators': 299, 'max_samples': 440}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:52:44,433] Trial 7 finished with value: -0.19545097009328483 and parameters: {'n_estimators': 139, 'max_samples': 1297}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:52:49,914] Trial 8 finished with value: -0.18500180895287777 and parameters: {'n_estimators': 82, 'max_samples': 1971}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:53:03,389] Trial 9 finished with value: -0.19137976613761154 and parameters: {'n_estimators': 218, 'max_samples': 996}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:53:18,677] Trial 10 finished with value: -0.19677755568436683 and parameters: {'n_estimators': 281, 'max_samples': 129}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:53:35,091] Trial 11 finished with value: -0.19594135976480756 and parameters: {'n_estimators': 248, 'max_samples': 551}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:53:41,415] Trial 12 finished with value: -0.1948367781518925 and parameters: {'n_estimators': 116, 'max_samples': 134}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:53:57,179] Trial 13 finished with value: -0.20021455687266504 and parameters: {'n_estimators': 252, 'max_samples': 571}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:54:08,424] Trial 14 finished with value: -0.1993687620247774 and parameters: {'n_estimators': 179, 'max_samples': 756}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:54:22,386] Trial 15 finished with value: -0.19814518145869275 and parameters: {'n_estimators': 245, 'max_samples': 366}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:54:30,675] Trial 16 finished with value: -0.20299465893804763 and parameters: {'n_estimators': 141, 'max_samples': 311}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:54:34,543] Trial 17 finished with value: -0.19705001418871687 and parameters: {'n_estimators': 60, 'max_samples': 752}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:54:47,708] Trial 18 finished with value: -0.1933682805662341 and parameters: {'n_estimators': 200, 'max_samples': 1657}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:55:04,016] Trial 19 finished with value: -0.1938902318980429 and parameters: {'n_estimators': 263, 'max_samples': 590}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:55:18,358] Trial 20 finished with value: -0.1967503923639093 and parameters: {'n_estimators': 229, 'max_samples': 935}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:55:26,595] Trial 21 finished with value: -0.1889195005674351 and parameters: {'n_estimators': 140, 'max_samples': 280}. Best is trial 1 with value: -0.20398252376278883.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:55:35,562] Trial 22 finished with value: -0.21095916845822543 and parameters: {'n_estimators': 154, 'max_samples': 294}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:55:44,401] Trial 23 finished with value: -0.19227055378316596 and parameters: {'n_estimators': 164, 'max_samples': 235}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:55:50,671] Trial 24 finished with value: -0.19885473056486466 and parameters: {'n_estimators': 108, 'max_samples': 441}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:56:02,788] Trial 25 finished with value: -0.2037101732820621 and parameters: {'n_estimators': 192, 'max_samples': 676}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:56:11,844] Trial 26 finished with value: -0.1979174556498859 and parameters: {'n_estimators': 157, 'max_samples': 463}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:56:22,546] Trial 27 finished with value: -0.19359740998922728 and parameters: {'n_estimators': 197, 'max_samples': 131}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:56:29,056] Trial 28 finished with value: -0.20147858303663327 and parameters: {'n_estimators': 112, 'max_samples': 261}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:56:43,485] Trial 29 finished with value: -0.19210736677873852 and parameters: {'n_estimators': 228, 'max_samples': 881}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:56:55,571] Trial 30 finished with value: -0.19329948472226424 and parameters: {'n_estimators': 193, 'max_samples': 736}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:57:07,822] Trial 31 finished with value: -0.19514298635812138 and parameters: {'n_estimators': 180, 'max_samples': 1090}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:57:19,514] Trial 32 finished with value: -0.20068004372541115 and parameters: {'n_estimators': 190, 'max_samples': 625}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:57:29,301] Trial 33 finished with value: -0.20214808461992756 and parameters: {'n_estimators': 159, 'max_samples': 671}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:57:42,751] Trial 34 finished with value: -0.1907018025757351 and parameters: {'n_estimators': 214, 'max_samples': 838}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:57:52,750] Trial 35 finished with value: -0.20218070573689476 and parameters: {'n_estimators': 172, 'max_samples': 477}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:58:06,092] Trial 36 finished with value: -0.19996754576424253 and parameters: {'n_estimators': 230, 'max_samples': 396}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:58:14,551] Trial 37 finished with value: -0.18633107655804504 and parameters: {'n_estimators': 124, 'max_samples': 1507}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:58:27,993] Trial 38 finished with value: -0.20151436495803965 and parameters: {'n_estimators': 202, 'max_samples': 1166}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:58:37,449] Trial 39 finished with value: -0.2076932511980291 and parameters: {'n_estimators': 151, 'max_samples': 539}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:58:44,425] Trial 40 finished with value: -0.19940975791076948 and parameters: {'n_estimators': 130, 'max_samples': 211}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:58:53,922] Trial 41 finished with value: -0.20452545525015844 and parameters: {'n_estimators': 153, 'max_samples': 522}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:02,675] Trial 42 finished with value: -0.19371494651775967 and parameters: {'n_estimators': 149, 'max_samples': 501}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:08,511] Trial 43 finished with value: -0.2037148155923351 and parameters: {'n_estimators': 100, 'max_samples': 348}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:14,162] Trial 44 finished with value: -0.20389013033835812 and parameters: {'n_estimators': 98, 'max_samples': 344}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:19,262] Trial 45 finished with value: -0.19464166384446516 and parameters: {'n_estimators': 94, 'max_samples': 231}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:22,956] Trial 46 finished with value: -0.1965033949249483 and parameters: {'n_estimators': 63, 'max_samples': 378}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:27,542] Trial 47 finished with value: -0.18854599156715768 and parameters: {'n_estimators': 91, 'max_samples': 111}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:32,699] Trial 48 finished with value: -0.1907624972645533 and parameters: {'n_estimators': 79, 'max_samples': 2044}. Best is trial 22 with value: -0.21095916845822543.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:40,626] Trial 49 finished with value: -0.21272432671142036 and parameters: {'n_estimators': 127, 'max_samples': 531}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:48,490] Trial 50 finished with value: -0.20004049570021729 and parameters: {'n_estimators': 128, 'max_samples': 525}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 06:59:57,181] Trial 51 finished with value: -0.20581398196886264 and parameters: {'n_estimators': 151, 'max_samples': 394}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:00:06,633] Trial 52 finished with value: -0.20774367704839092 and parameters: {'n_estimators': 149, 'max_samples': 574}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:00:17,103] Trial 53 finished with value: -0.2014592691295729 and parameters: {'n_estimators': 167, 'max_samples': 560}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:00:25,740] Trial 54 finished with value: -0.19993861380203082 and parameters: {'n_estimators': 145, 'max_samples': 422}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:00:35,611] Trial 55 finished with value: -0.1947275837194747 and parameters: {'n_estimators': 154, 'max_samples': 625}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:00:43,934] Trial 56 finished with value: -0.18922849855069496 and parameters: {'n_estimators': 131, 'max_samples': 806}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:00:54,725] Trial 57 finished with value: -0.20289852307929107 and parameters: {'n_estimators': 172, 'max_samples': 707}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:01:01,403] Trial 58 finished with value: -0.20129408234730314 and parameters: {'n_estimators': 120, 'max_samples': 190}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:01:10,068] Trial 59 finished with value: -0.20107356908737814 and parameters: {'n_estimators': 137, 'max_samples': 950}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:01:19,690] Trial 60 finished with value: -0.21029871940310418 and parameters: {'n_estimators': 152, 'max_samples': 519}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:01:29,234] Trial 61 finished with value: -0.20114281745280474 and parameters: {'n_estimators': 151, 'max_samples': 531}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:01:37,712] Trial 62 finished with value: -0.2014819002732357 and parameters: {'n_estimators': 136, 'max_samples': 605}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:01:47,040] Trial 63 finished with value: -0.19537494004715925 and parameters: {'n_estimators': 161, 'max_samples': 297}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:01:55,709] Trial 64 finished with value: -0.20390346247021515 and parameters: {'n_estimators': 148, 'max_samples': 434}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:02:07,254] Trial 65 finished with value: -0.19772868968276108 and parameters: {'n_estimators': 183, 'max_samples': 777}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:02:14,967] Trial 66 finished with value: -0.1999179818624083 and parameters: {'n_estimators': 116, 'max_samples': 1770}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:02:24,850] Trial 67 finished with value: -0.1961928753012005 and parameters: {'n_estimators': 169, 'max_samples': 318}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:02:33,102] Trial 68 finished with value: -0.20533237632389906 and parameters: {'n_estimators': 141, 'max_samples': 484}. Best is trial 49 with value: -0.21272432671142036.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:02:39,231] Trial 69 finished with value: -0.21347754614287726 and parameters: {'n_estimators': 106, 'max_samples': 461}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:02:46,160] Trial 70 finished with value: -0.20420819051607556 and parameters: {'n_estimators': 112, 'max_samples': 661}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:02:54,357] Trial 71 finished with value: -0.2072378354232824 and parameters: {'n_estimators': 141, 'max_samples': 463}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:03:00,444] Trial 72 finished with value: -0.1988800493212027 and parameters: {'n_estimators': 105, 'max_samples': 416}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:03:07,119] Trial 73 finished with value: -0.1899621510121924 and parameters: {'n_estimators': 122, 'max_samples': 185}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:03:17,027] Trial 74 finished with value: -0.20674328748014165 and parameters: {'n_estimators': 161, 'max_samples': 584}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:03:28,065] Trial 75 finished with value: -0.20436088286567025 and parameters: {'n_estimators': 176, 'max_samples': 585}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:03:36,561] Trial 76 finished with value: -0.19069562593892395 and parameters: {'n_estimators': 135, 'max_samples': 693}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:03:46,726] Trial 77 finished with value: -0.1991846004233615 and parameters: {'n_estimators': 163, 'max_samples': 626}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:03:51,546] Trial 78 finished with value: -0.19908840456709756 and parameters: {'n_estimators': 83, 'max_samples': 470}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:04:00,619] Trial 79 finished with value: -0.20285217251200524 and parameters: {'n_estimators': 144, 'max_samples': 557}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:04:08,583] Trial 80 finished with value: -0.1928493725925751 and parameters: {'n_estimators': 127, 'max_samples': 734}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:04:17,703] Trial 81 finished with value: -0.1946471945839179 and parameters: {'n_estimators': 158, 'max_samples': 380}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:04:26,265] Trial 82 finished with value: -0.19923972661035494 and parameters: {'n_estimators': 147, 'max_samples': 265}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:04:35,221] Trial 83 finished with value: -0.20061194487423434 and parameters: {'n_estimators': 155, 'max_samples': 330}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:04:42,990] Trial 84 finished with value: -0.19910039368268737 and parameters: {'n_estimators': 135, 'max_samples': 466}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:04:52,605] Trial 85 finished with value: -0.19039989185564468 and parameters: {'n_estimators': 166, 'max_samples': 406}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:05:02,997] Trial 86 finished with value: -0.19853813240331214 and parameters: {'n_estimators': 176, 'max_samples': 510}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:05:21,531] Trial 87 finished with value: -0.19848495482204354 and parameters: {'n_estimators': 295, 'max_samples': 652}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:05:30,616] Trial 88 finished with value: -0.20115180355085785 and parameters: {'n_estimators': 142, 'max_samples': 571}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:05:37,451] Trial 89 finished with value: -0.2084670078078786 and parameters: {'n_estimators': 118, 'max_samples': 286}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:05:44,252] Trial 90 finished with value: -0.1939879621655532 and parameters: {'n_estimators': 117, 'max_samples': 351}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:05:51,758] Trial 91 finished with value: -0.1933984116531754 and parameters: {'n_estimators': 129, 'max_samples': 281}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:00,662] Trial 92 finished with value: -0.19021410638457062 and parameters: {'n_estimators': 152, 'max_samples': 435}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:06,715] Trial 93 finished with value: -0.1860929878220503 and parameters: {'n_estimators': 108, 'max_samples': 152}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:13,462] Trial 94 finished with value: -0.19080226783100146 and parameters: {'n_estimators': 125, 'max_samples': 244}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:21,042] Trial 95 finished with value: -0.1955742551274973 and parameters: {'n_estimators': 132, 'max_samples': 498}. Best is trial 69 with value: -0.21347754614287726.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:29,313] Trial 96 finished with value: -0.21640615903320576 and parameters: {'n_estimators': 143, 'max_samples': 307}. Best is trial 96 with value: -0.21640615903320576.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:39,828] Trial 97 finished with value: -0.19880214814934785 and parameters: {'n_estimators': 158, 'max_samples': 1229}. Best is trial 96 with value: -0.21640615903320576.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:47,939] Trial 98 finished with value: -0.20325597984613486 and parameters: {'n_estimators': 142, 'max_samples': 322}. Best is trial 96 with value: -0.21640615903320576.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# [I 2025-05-20 07:06:57,929] Trial 99 finished with value: -0.1999732100727559 and parameters: {'n_estimators': 187, 'max_samples': 181}. Best is trial 96 with value: -0.21640615903320576.
# Kết quả tối ưu hóa:
# Tham số tốt nhất: {'n_estimators': 143, 'max_samples': 307}
# Giá trị hàm mục tiêu tốt nhất (âm của sự khác biệt trung vị): -0.21640615903320576

# %%
best_params = study.best_params
best_model = IsolationForest(n_estimators=best_params['n_estimators'],
                             max_samples=best_params['max_samples'],
                             contamination=estimated_contamination, 
                             random_state=42) 

# Fit mô hình tốt nhất với toàn bộ dữ liệu để sử dụng
best_model.fit(X)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.005, max_samples=307, n_estimators=143,
#                 random_state=42)

# %%
# Bây giờ bạn có thể sử dụng best_model để tính điểm bất thường và dự đoán nhãn
anomaly_scores_tuned = best_model.decision_function(X)
predictions_tuned = best_model.predict(X)

# %%
df['anomaly_score_isolation_forest'] = anomaly_scores_tuned
df['is_outlier_isolation_forest'] = predictions_tuned

# %%
# Xem 10 hàng có điểm bất thường thấp nhất (bất thường nhất)
top_anomalies = df.sort_values(by='anomaly_score_isolation_forest').head(10)
print("\nTop 10 ứng viên Rug Pull dựa trên điểm bất thường:")
print(top_anomalies)

# Xem tất cả các hàng được dự đoán là outliers (-1)
predicted_outliers_df = df[df['is_outlier_isolation_forest'] == -1]
print(f"\nSố lượng điểm được dự đoán là outliers: {len(predicted_outliers_df)}")
print("Thông tin về các điểm được dự đoán là outliers:")
print(predicted_outliers_df.head())
# Out:
# Top 10 ứng viên Rug Pull dựa trên điểm bất thường:
#                              LIQUIDITY_POOL_ADDRESS  \
# 11961  5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om
# 82222  4sq2VviSRTNDg1Fdm1VzbbeCWgkqFJtWWAqHhfAYFrXs
# 91575  137Wy4xiPi6j7ssUaowH2DVg972Juf4btmg6p8LfgsnH
# 47606  Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy
# 55636  BAxJwA7FMcHjmZVwFp2a1sGqKu6b8npJZovD4rEM4TkK
# 91458  3V3ZjMLfyXrWKCQ9JiD6Yv7SBHyX7Q2uYCEKVGuj9PYw
# 91248  FTrERt9XSJ4jUSPcxeqKESe8SS348uaaVGUWQKi1BqKR
# 88888  7RUSgjFttQRonLBkvwRqENR3GMeqBm7aNkLQQwKAX5Zy
# 82756  95rearCVnMKa7hfBC8R6NLaN5Kw1xxBSruG1eX33VsA4
# 47913  8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq
#
#                                                MINT  TOTAL_ADDED_LIQUIDITY  \
# 11961  8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw           5.000000e+14
# 82222  GpLGcXFdL5evTKqZBWvM6p8yGCTWH9YnK3mk4kJZYpc7           2.184661e+14
# 91575  23h3L2UxzdsmWntfAGJQNcFZ7iQb5sgzMR2JbaoduCmc           7.090737e+13
# 47606  4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y           6.859382e+10
# 55636  8exuywH7jW6AXBAb9f878uddLpPHjJFtNTxjZCjW4L3J           3.446811e+13
# 91458  A8Kj9RK5ptAs1XntDcbpZzsa7ALYY11hsA7EKuTAKjix           8.554760e+11
# 91248  5XY9W1q3aRxueZcTYpNk2VnsAS2Vu27etgAQShegeGyH           2.256390e+15
# 88888  8hS1TLmxWhT3C42i6Bnb8Bj2s1o5YN9W2c1JDmdH4JsC           1.659162e+14
# 82756  7vNuRmaESRCKNGaxb5kHhszDxTSdmyEhNR6n2nEehKyF           1.000000e+12
# 47913  5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb           6.602291e+10
#
#        TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 11961             5.000000e+14                 1.0                    1.0
# 82222             1.937779e+14                 8.0                  134.0
# 91575             6.730713e+13                10.0                   40.0
# 47606             2.524209e+03                 6.0                    5.0
# 55636             3.211485e+08                 4.0                    4.0
# 91458             8.554760e+11                 4.0                    4.0
# 91248             5.139538e+15               138.0                   78.0
# 88888             4.231226e+14               230.0                  104.0
# 82756             1.000000e+12                 2.0                    4.0
# 47913             3.229444e+03                 2.0                    1.0
#
#        ADD_TO_REMOVE_RATIO  LAST_POOL_ACTIVITY_TIMESTAMP_ts  \
# 11961         1.000000e+00                       1727392728
# 82222         1.127405e+00                       1711494201
# 91575         1.053490e+00                       1705254323
# 47606         2.717439e+07                       1728870578
# 55636         1.073276e+05                       1718043620
# 91458         1.000000e+00                       1704501163
# 91248         4.390258e-01                       1716145052
# 88888         3.921232e-01                       1718302344
# 82756         1.000000e+00                       1706922659
# 47913         2.044405e+07                       1728871018
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_ts  LAST_SWAP_TIMESTAMP_ts  ...  \
# 11961                        1727391322             -9223372037  ...
# 82222                        1707073198             -9223372037  ...
# 91575                        1704467868             -9223372037  ...
# 47606                        1717552481             -9223372037  ...
# 55636                        1715647495             -9223372037  ...
# 91458                        1704500890             -9223372037  ...
# 91248                        1704566617              1713273651  ...
# 88888                        1705245215              1714599875  ...
# 82756                        1706920217             -9223372037  ...
# 47913                        1717480275             -9223372037  ...
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  \
# 11961                                    3.0
# 82222                                    6.0
# 91575                                    4.0
# 47606                                    2.0
# 55636                                    1.0
# 91458                                    5.0
# 91248                                    5.0
# 88888                                    6.0
# 82756                                    5.0
# 47913                                    1.0
#
#        FIRST_POOL_ACTIVITY_TIMESTAMP_month  LAST_SWAP_TIMESTAMP_hour  \
# 11961                                  9.0                      -1.0
# 82222                                  2.0                      -1.0
# 91575                                  1.0                      -1.0
# 47606                                  6.0                      -1.0
# 55636                                  5.0                      -1.0
# 91458                                  1.0                      -1.0
# 91248                                  1.0                      13.0
# 88888                                  1.0                      21.0
# 82756                                  2.0                      -1.0
# 47913                                  6.0                      -1.0
#
#        LAST_SWAP_TIMESTAMP_day  LAST_SWAP_TIMESTAMP_weekday  \
# 11961                     -1.0                         -1.0
# 82222                     -1.0                         -1.0
# 91575                     -1.0                         -1.0
# 47606                     -1.0                         -1.0
# 55636                     -1.0                         -1.0
# 91458                     -1.0                         -1.0
# 91248                     16.0                          1.0
# 88888                      1.0                          2.0
# 82756                     -1.0                         -1.0
# 47913                     -1.0                         -1.0
#
#        LAST_SWAP_TIMESTAMP_month  INACTIVITY_STATUS_Active  \
# 11961                       -1.0                     False
# 82222                       -1.0                     False
# 91575                       -1.0                     False
# 47606                       -1.0                     False
# 55636                       -1.0                     False
# 91458                       -1.0                     False
# 91248                        4.0                     False
# 88888                        5.0                     False
# 82756                       -1.0                     False
# 47913                       -1.0                     False
#
#        INACTIVITY_STATUS_Inactive  anomaly_score_isolation_forest  \
# 11961                        True                       -0.093311
# 82222                        True                       -0.089092
# 91575                        True                       -0.085830
# 47606                        True                       -0.080054
# 55636                        True                       -0.079847
# 91458                        True                       -0.077112
# 91248                        True                       -0.072878
# 88888                        True                       -0.072128
# 82756                        True                       -0.071493
# 47913                        True                       -0.068591
#
#        is_outlier_isolation_forest
# 11961                           -1
# 82222                           -1
# 91575                           -1
# 47606                           -1
# 55636                           -1
# 91458                           -1
# 91248                           -1
# 88888                           -1
# 82756                           -1
# 47913                           -1
#
# [10 rows x 26 columns]
#
# Số lượng điểm được dự đoán là outliers: 478
# Thông tin về các điểm được dự đoán là outliers:
#                             LIQUIDITY_POOL_ADDRESS  \
# 3886   dT9HnnCirVWgSnbUGRuWBH8e2AB3PyzucY4YXrVTCdq
# 4028  9p4LGr6oAHWie8A8QGtS1BZUyBRvCBezo9uj8Fpbg9g4
# 4035  758qMvzhprFy7jUUDED8374XYhxUweJXWV1DF3Y9Moiz
# 5268  912bQ642GgLFDyxMk5m2TV3v2eTa8HcGzpLRBpiu1xra
# 6465  4amqJ23mX5Uzvmi2omUs8gNvpZjb1Ef97KDDBSDLq4LL
#
#                                               MINT  TOTAL_ADDED_LIQUIDITY  \
# 3886  7HcgDrtZPGBPVdC2cWSm1oomuX8Lt9JZAuq5jyyRXRcN           1.510000e+09
# 4028  CgFdo4U7Vd1PviMM2yvbhVpaZDVtaxwVA6m8Z3vdArJx           9.000000e+09
# 4035  6AnCzGMAbEzKq3CyE4DvujNgMxk9dyJugsdmkEPQQhQp           7.044254e+07
# 5268  4AmRnkeg4ZjWjWQQsGxUnEHEZcHsLXEKFCXx4LqZcLot           9.449691e+08
# 6465  GyCenQmE5Ncx27Hgf2m9auNqD2gouVbRryFj5YbdBTwy           1.050000e+08
#
#       TOTAL_REMOVED_LIQUIDITY  NUM_LIQUIDITY_ADDS  NUM_LIQUIDITY_REMOVES  \
# 3886             1.510000e+09                 3.0                    2.0
# 4028             9.000000e+09                 1.0                    2.0
# 4035             7.044253e+07                 2.0                    1.0
# 5268             9.449691e+08                 2.0                    2.0
# 6465             1.050000e+08                 1.0                    1.0
#
#       ADD_TO_REMOVE_RATIO  LAST_POOL_ACTIVITY_TIMESTAMP_ts  \
# 3886                  1.0                       1729498489
# 4028                  1.0                       1729473076
# 4035                  1.0                       1729473168
# 5268                  1.0                       1729194429
# 6465                  1.0                       1728932387
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP_ts  LAST_SWAP_TIMESTAMP_ts  ...  \
# 3886                        1729484012             -9223372037  ...
# 4028                        1729449831             -9223372037  ...
# 4035                        1729447850             -9223372037  ...
# 5268                        1729189869             -9223372037  ...
# 6465                        1728930045             -9223372037  ...
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP_weekday  \
# 3886                                    0.0
# 4028                                    6.0
# 4035                                    6.0
# 5268                                    3.0
# 6465                                    0.0
#
#       FIRST_POOL_ACTIVITY_TIMESTAMP_month  LAST_SWAP_TIMESTAMP_hour  \
# 3886                                 10.0                      -1.0
# 4028                                 10.0                      -1.0
# 4035                                 10.0                      -1.0
# 5268                                 10.0                      -1.0
# 6465                                 10.0                      -1.0
#
#       LAST_SWAP_TIMESTAMP_day  LAST_SWAP_TIMESTAMP_weekday  \
# 3886                     -1.0                         -1.0
# 4028                     -1.0                         -1.0
# 4035                     -1.0                         -1.0
# 5268                     -1.0                         -1.0
# 6465                     -1.0                         -1.0
#
#       LAST_SWAP_TIMESTAMP_month  INACTIVITY_STATUS_Active  \
# 3886                       -1.0                     False
# 4028                       -1.0                     False
# 4035                       -1.0                     False
# 5268                       -1.0                     False
# 6465                       -1.0                     False
#
#       INACTIVITY_STATUS_Inactive  anomaly_score_isolation_forest  \
# 3886                        True                       -0.008570
# 4028                        True                       -0.028386
# 4035                        True                       -0.015220
# 5268                        True                       -0.003296
# 6465                        True                       -0.004651
#
#       is_outlier_isolation_forest
# 3886                           -1
# 4028                           -1
# 4035                           -1
# 5268                           -1
# 6465                           -1
#
# [5 rows x 26 columns]

# %%
anomaly_candidates_df = df[df['is_outlier_isolation_forest'] == -1]
anomaly_candidates_df.head(1).to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {3886: 'dT9HnnCirVWgSnbUGRuWBH8e2AB3PyzucY4YXrVTCdq'},
#  'MINT': {3886: '7HcgDrtZPGBPVdC2cWSm1oomuX8Lt9JZAuq5jyyRXRcN'},
#  'TOTAL_ADDED_LIQUIDITY': {3886: 1510000000.0},
#  'TOTAL_REMOVED_LIQUIDITY': {3886: 1509999999.99923},
#  'NUM_LIQUIDITY_ADDS': {3886: 3.0},
#  'NUM_LIQUIDITY_REMOVES': {3886: 2.0},
#  'ADD_TO_REMOVE_RATIO': {3886: 1.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts': {3886: 1729498489},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': {3886: 1729484012},
#  'LAST_SWAP_TIMESTAMP_ts': {3886: -9223372037},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour': {3886: 8.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day': {3886: 21.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': {3886: 0.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month': {3886: 10.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': {3886: 4.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day': {3886: 21.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': {3886: 0.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month': {3886: 10.0},
#  'LAST_SWAP_TIMESTAMP_hour': {3886: -1.0},
#  'LAST_SWAP_TIMESTAMP_day': {3886: -1.0},
#  'LAST_SWAP_TIMESTAMP_weekday': {3886: -1.0},
#  'LAST_SWAP_TIMESTAMP_month': {3886: -1.0},
#  'INACTIVITY_STATUS_Active': {3886: False},
#  'INACTIVITY_STATUS_Inactive': {3886: True},
#  'anomaly_score_isolation_forest': {3886: -0.008569672944682694},
#  'is_outlier_isolation_forest': {3886: -1}}

# %%
subset_to_label = df.sort_values(by='anomaly_score_isolation_forest').head(478)
indices_to_label = subset_to_label.index

# %%
df['true_label'] = np.nan

# %%
import joblib
import os 
output_dir = '/kaggle/working/'

model_filename = 'isolation_forest_model.joblib'

# Tạo đường dẫn đầy đủ để lưu file
output_path = os.path.join(output_dir, model_filename)

print(f"Saving modelt o: {output_path}")
joblib.dump(best_model, output_path)
print("Saving model successfully.")
# Out:
# Saving modelt o: /kaggle/working/isolation_forest_model.joblib
# Saving model successfully.

# %%
subset_to_label.head(10).to_dict()
# Out:
# {'LIQUIDITY_POOL_ADDRESS': {11961: '5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om',
#   82222: '4sq2VviSRTNDg1Fdm1VzbbeCWgkqFJtWWAqHhfAYFrXs',
#   91575: '137Wy4xiPi6j7ssUaowH2DVg972Juf4btmg6p8LfgsnH',
#   47606: 'Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy',
#   55636: 'BAxJwA7FMcHjmZVwFp2a1sGqKu6b8npJZovD4rEM4TkK',
#   91458: '3V3ZjMLfyXrWKCQ9JiD6Yv7SBHyX7Q2uYCEKVGuj9PYw',
#   91248: 'FTrERt9XSJ4jUSPcxeqKESe8SS348uaaVGUWQKi1BqKR',
#   88888: '7RUSgjFttQRonLBkvwRqENR3GMeqBm7aNkLQQwKAX5Zy',
#   82756: '95rearCVnMKa7hfBC8R6NLaN5Kw1xxBSruG1eX33VsA4',
#   47913: '8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq'},
#  'MINT': {11961: '8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw',
#   82222: 'GpLGcXFdL5evTKqZBWvM6p8yGCTWH9YnK3mk4kJZYpc7',
#   91575: '23h3L2UxzdsmWntfAGJQNcFZ7iQb5sgzMR2JbaoduCmc',
#   47606: '4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y',
#   55636: '8exuywH7jW6AXBAb9f878uddLpPHjJFtNTxjZCjW4L3J',
#   91458: 'A8Kj9RK5ptAs1XntDcbpZzsa7ALYY11hsA7EKuTAKjix',
#   91248: '5XY9W1q3aRxueZcTYpNk2VnsAS2Vu27etgAQShegeGyH',
#   88888: '8hS1TLmxWhT3C42i6Bnb8Bj2s1o5YN9W2c1JDmdH4JsC',
#   82756: '7vNuRmaESRCKNGaxb5kHhszDxTSdmyEhNR6n2nEehKyF',
#   47913: '5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb'},
#  'TOTAL_ADDED_LIQUIDITY': {11961: 499999999999997.0,
#   82222: 218466113983500.0,
#   91575: 70907372981422.9,
#   47606: 68593822519.1516,
#   55636: 34468110069736.2,
#   91458: 855475957526.292,
#   91248: 2256389878570720.0,
#   88888: 165916201929092.0,
#   82756: 999999999999.997,
#   47913: 66022910039.2474},
#  'TOTAL_REMOVED_LIQUIDITY': {11961: 499999999999997.0,
#   82222: 193777880726481.0,
#   91575: 67307125634181.2,
#   47606: 2524.208505,
#   55636: 321148468.190506,
#   91458: 855475957526.292,
#   91248: 5139537736542900.0,
#   88888: 423122614640657.0,
#   82756: 999999999999.997,
#   47913: 3229.443534},
#  'NUM_LIQUIDITY_ADDS': {11961: 1.0,
#   82222: 8.0,
#   91575: 10.0,
#   47606: 6.0,
#   55636: 4.0,
#   91458: 4.0,
#   91248: 138.0,
#   88888: 230.0,
#   82756: 2.0,
#   47913: 2.0},
#  'NUM_LIQUIDITY_REMOVES': {11961: 1.0,
#   82222: 134.0,
#   91575: 40.0,
#   47606: 5.0,
#   55636: 4.0,
#   91458: 4.0,
#   91248: 78.0,
#   88888: 104.0,
#   82756: 4.0,
#   47913: 1.0},
#  'ADD_TO_REMOVE_RATIO': {11961: 1.0,
#   82222: 1.127404806,
#   91575: 1.053489839,
#   47606: 27174388.4799055,
#   55636: 107327.648996568,
#   91458: 1.0,
#   91248: 0.4390258413,
#   88888: 0.3921232196,
#   82756: 1.0,
#   47913: 20444051.5352412},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_ts': {11961: 1727392728,
#   82222: 1711494201,
#   91575: 1705254323,
#   47606: 1728870578,
#   55636: 1718043620,
#   91458: 1704501163,
#   91248: 1716145052,
#   88888: 1718302344,
#   82756: 1706922659,
#   47913: 1728871018},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': {11961: 1727391322,
#   82222: 1707073198,
#   91575: 1704467868,
#   47606: 1717552481,
#   55636: 1715647495,
#   91458: 1704500890,
#   91248: 1704566617,
#   88888: 1705245215,
#   82756: 1706920217,
#   47913: 1717480275},
#  'LAST_SWAP_TIMESTAMP_ts': {11961: -9223372037,
#   82222: -9223372037,
#   91575: -9223372037,
#   47606: -9223372037,
#   55636: -9223372037,
#   91458: -9223372037,
#   91248: 1713273651,
#   88888: 1714599875,
#   82756: -9223372037,
#   47913: -9223372037},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_hour': {11961: 23.0,
#   82222: 23.0,
#   91575: 17.0,
#   47606: 1.0,
#   55636: 18.0,
#   91458: 0.0,
#   91248: 18.0,
#   88888: 18.0,
#   82756: 1.0,
#   47913: 1.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_day': {11961: 26.0,
#   82222: 26.0,
#   91575: 14.0,
#   47606: 14.0,
#   55636: 10.0,
#   91458: 6.0,
#   91248: 19.0,
#   88888: 13.0,
#   82756: 3.0,
#   47913: 14.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': {11961: 3.0,
#   82222: 1.0,
#   91575: 6.0,
#   47606: 0.0,
#   55636: 0.0,
#   91458: 5.0,
#   91248: 6.0,
#   88888: 3.0,
#   82756: 5.0,
#   47913: 0.0},
#  'LAST_POOL_ACTIVITY_TIMESTAMP_month': {11961: 9.0,
#   82222: 3.0,
#   91575: 1.0,
#   47606: 10.0,
#   55636: 6.0,
#   91458: 1.0,
#   91248: 5.0,
#   88888: 6.0,
#   82756: 2.0,
#   47913: 10.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': {11961: 22.0,
#   82222: 18.0,
#   91575: 15.0,
#   47606: 1.0,
#   55636: 0.0,
#   91458: 0.0,
#   91248: 18.0,
#   88888: 15.0,
#   82756: 0.0,
#   47913: 5.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_day': {11961: 26.0,
#   82222: 4.0,
#   91575: 5.0,
#   47606: 5.0,
#   55636: 14.0,
#   91458: 6.0,
#   91248: 6.0,
#   88888: 14.0,
#   82756: 3.0,
#   47913: 4.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': {11961: 3.0,
#   82222: 6.0,
#   91575: 4.0,
#   47606: 2.0,
#   55636: 1.0,
#   91458: 5.0,
#   91248: 5.0,
#   88888: 6.0,
#   82756: 5.0,
#   47913: 1.0},
#  'FIRST_POOL_ACTIVITY_TIMESTAMP_month': {11961: 9.0,
#   82222: 2.0,
#   91575: 1.0,
#   47606: 6.0,
#   55636: 5.0,
#   91458: 1.0,
#   91248: 1.0,
#   88888: 1.0,
#   82756: 2.0,
#   47913: 6.0},
#  'LAST_SWAP_TIMESTAMP_hour': {11961: -1.0,
#   82222: -1.0,
#   91575: -1.0,
#   47606: -1.0,
#   55636: -1.0,
#   91458: -1.0,
#   91248: 13.0,
#   88888: 21.0,
#   82756: -1.0,
#   47913: -1.0},
#  'LAST_SWAP_TIMESTAMP_day': {11961: -1.0,
#   82222: -1.0,
#   91575: -1.0,
#   47606: -1.0,
#   55636: -1.0,
#   91458: -1.0,
#   91248: 16.0,
#   88888: 1.0,
#   82756: -1.0,
#   47913: -1.0},
#  'LAST_SWAP_TIMESTAMP_weekday': {11961: -1.0,
#   82222: -1.0,
#   91575: -1.0,
#   47606: -1.0,
#   55636: -1.0,
#   91458: -1.0,
#   91248: 1.0,
#   88888: 2.0,
#   82756: -1.0,
#   47913: -1.0},
#  'LAST_SWAP_TIMESTAMP_month': {11961: -1.0,
#   82222: -1.0,
#   91575: -1.0,
#   47606: -1.0,
#   55636: -1.0,
#   91458: -1.0,
#   91248: 4.0,
#   88888: 5.0,
#   82756: -1.0,
#   47913: -1.0},
#  'INACTIVITY_STATUS_Active': {11961: False,
#   82222: False,
#   91575: False,
#   47606: False,
#   55636: False,
#   91458: False,
#   91248: False,
#   88888: False,
#   82756: False,
#   47913: False},
#  'INACTIVITY_STATUS_Inactive': {11961: True,
#   82222: True,
#   91575: True,
#   47606: True,
#   55636: True,
#   91458: True,
#   91248: True,
#   88888: True,
#   82756: True,
#   47913: True},
#  'anomaly_score_isolation_forest': {11961: -0.09331102104436595,
#   82222: -0.08909234614586403,
#   91575: -0.08582962836351749,
#   47606: -0.08005388213169518,
#   55636: -0.07984674972777794,
#   91458: -0.07711182362946645,
#   91248: -0.07287830708957477,
#   88888: -0.07212817023064033,
#   82756: -0.07149301506409544,
#   47913: -0.06859076456294833},
#  'is_outlier_isolation_forest': {11961: -1,
#   82222: -1,
#   91575: -1,
#   47606: -1,
#   55636: -1,
#   91458: -1,
#   91248: -1,
#   88888: -1,
#   82756: -1,
#   47913: -1}}

# %%
for i, row in subset_to_label.head(30).iterrows():
    print(f"Index: {i}, Data: {row.to_dict()}")
# Out:
# Index: 11961, Data: {'LIQUIDITY_POOL_ADDRESS': '5no8Tr7WBcXjTEwtLa6MVuzFvL6Liv1rnki3AFhFv1om', 'MINT': '8RweLrRJ7kQ1Kk6Uqd3fs8Hees295p3CYa7yiycGH8Lw', 'TOTAL_ADDED_LIQUIDITY': 499999999999997.0, 'TOTAL_REMOVED_LIQUIDITY': 499999999999997.0, 'NUM_LIQUIDITY_ADDS': 1.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1727392728, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1727391322, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.09331102104436595, 'is_outlier_isolation_forest': -1}
# Index: 82222, Data: {'LIQUIDITY_POOL_ADDRESS': '4sq2VviSRTNDg1Fdm1VzbbeCWgkqFJtWWAqHhfAYFrXs', 'MINT': 'GpLGcXFdL5evTKqZBWvM6p8yGCTWH9YnK3mk4kJZYpc7', 'TOTAL_ADDED_LIQUIDITY': 218466113983500.0, 'TOTAL_REMOVED_LIQUIDITY': 193777880726481.0, 'NUM_LIQUIDITY_ADDS': 8.0, 'NUM_LIQUIDITY_REMOVES': 134.0, 'ADD_TO_REMOVE_RATIO': 1.127404806, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1711494201, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1707073198, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 2.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08909234614586403, 'is_outlier_isolation_forest': -1}
# Index: 91575, Data: {'LIQUIDITY_POOL_ADDRESS': '137Wy4xiPi6j7ssUaowH2DVg972Juf4btmg6p8LfgsnH', 'MINT': '23h3L2UxzdsmWntfAGJQNcFZ7iQb5sgzMR2JbaoduCmc', 'TOTAL_ADDED_LIQUIDITY': 70907372981422.9, 'TOTAL_REMOVED_LIQUIDITY': 67307125634181.2, 'NUM_LIQUIDITY_ADDS': 10.0, 'NUM_LIQUIDITY_REMOVES': 40.0, 'ADD_TO_REMOVE_RATIO': 1.053489839, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1705254323, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704467868, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 17.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08582962836351749, 'is_outlier_isolation_forest': -1}
# Index: 47606, Data: {'LIQUIDITY_POOL_ADDRESS': 'Fptmpk3UW6KcVTFFpoWv53eiji8dn2jVaZDNhHEhxCYy', 'MINT': '4XgoqVmM4D3ts697pghaCZcK2JvsdA8JYCxc4aerZF2Y', 'TOTAL_ADDED_LIQUIDITY': 68593822519.1516, 'TOTAL_REMOVED_LIQUIDITY': 2524.208505, 'NUM_LIQUIDITY_ADDS': 6.0, 'NUM_LIQUIDITY_REMOVES': 5.0, 'ADD_TO_REMOVE_RATIO': 27174388.4799055, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728870578, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1717552481, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.08005388213169518, 'is_outlier_isolation_forest': -1}
# Index: 55636, Data: {'LIQUIDITY_POOL_ADDRESS': 'BAxJwA7FMcHjmZVwFp2a1sGqKu6b8npJZovD4rEM4TkK', 'MINT': '8exuywH7jW6AXBAb9f878uddLpPHjJFtNTxjZCjW4L3J', 'TOTAL_ADDED_LIQUIDITY': 34468110069736.2, 'TOTAL_REMOVED_LIQUIDITY': 321148468.190506, 'NUM_LIQUIDITY_ADDS': 4.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 107327.648996568, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1718043620, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1715647495, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 10.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07984674972777794, 'is_outlier_isolation_forest': -1}
# Index: 91458, Data: {'LIQUIDITY_POOL_ADDRESS': '3V3ZjMLfyXrWKCQ9JiD6Yv7SBHyX7Q2uYCEKVGuj9PYw', 'MINT': 'A8Kj9RK5ptAs1XntDcbpZzsa7ALYY11hsA7EKuTAKjix', 'TOTAL_ADDED_LIQUIDITY': 855475957526.292, 'TOTAL_REMOVED_LIQUIDITY': 855475957526.292, 'NUM_LIQUIDITY_ADDS': 4.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1704501163, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704500890, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07711182362946645, 'is_outlier_isolation_forest': -1}
# Index: 91248, Data: {'LIQUIDITY_POOL_ADDRESS': 'FTrERt9XSJ4jUSPcxeqKESe8SS348uaaVGUWQKi1BqKR', 'MINT': '5XY9W1q3aRxueZcTYpNk2VnsAS2Vu27etgAQShegeGyH', 'TOTAL_ADDED_LIQUIDITY': 2256389878570720.0, 'TOTAL_REMOVED_LIQUIDITY': 5139537736542900.0, 'NUM_LIQUIDITY_ADDS': 138.0, 'NUM_LIQUIDITY_REMOVES': 78.0, 'ADD_TO_REMOVE_RATIO': 0.4390258413, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1716145052, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704566617, 'LAST_SWAP_TIMESTAMP_ts': 1713273651, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 13.0, 'LAST_SWAP_TIMESTAMP_day': 16.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 4.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07287830708957477, 'is_outlier_isolation_forest': -1}
# Index: 88888, Data: {'LIQUIDITY_POOL_ADDRESS': '7RUSgjFttQRonLBkvwRqENR3GMeqBm7aNkLQQwKAX5Zy', 'MINT': '8hS1TLmxWhT3C42i6Bnb8Bj2s1o5YN9W2c1JDmdH4JsC', 'TOTAL_ADDED_LIQUIDITY': 165916201929092.0, 'TOTAL_REMOVED_LIQUIDITY': 423122614640657.0, 'NUM_LIQUIDITY_ADDS': 230.0, 'NUM_LIQUIDITY_REMOVES': 104.0, 'ADD_TO_REMOVE_RATIO': 0.3921232196, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1718302344, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1705245215, 'LAST_SWAP_TIMESTAMP_ts': 1714599875, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 13.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 15.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 21.0, 'LAST_SWAP_TIMESTAMP_day': 1.0, 'LAST_SWAP_TIMESTAMP_weekday': 2.0, 'LAST_SWAP_TIMESTAMP_month': 5.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07212817023064033, 'is_outlier_isolation_forest': -1}
# Index: 82756, Data: {'LIQUIDITY_POOL_ADDRESS': '95rearCVnMKa7hfBC8R6NLaN5Kw1xxBSruG1eX33VsA4', 'MINT': '7vNuRmaESRCKNGaxb5kHhszDxTSdmyEhNR6n2nEehKyF', 'TOTAL_ADDED_LIQUIDITY': 999999999999.997, 'TOTAL_REMOVED_LIQUIDITY': 999999999999.997, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706922659, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706920217, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 2.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.07149301506409544, 'is_outlier_isolation_forest': -1}
# Index: 47913, Data: {'LIQUIDITY_POOL_ADDRESS': '8bCQiauSvZjB2FSL83pVHMZrgfFbYY5ff7cdMUpz4FVq', 'MINT': '5adgZL4TvU4GnaJ76g91up8AaLj7cqu3CvYyVXmSNPdb', 'TOTAL_ADDED_LIQUIDITY': 66022910039.2474, 'TOTAL_REMOVED_LIQUIDITY': 3229.443534, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 20444051.5352412, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728871018, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1717480275, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06859076456294833, 'is_outlier_isolation_forest': -1}
# Index: 51323, Data: {'LIQUIDITY_POOL_ADDRESS': '4QzJqjUhedncg4m9keRmz7dAjfb9Et8VfBcMEew5sA1U', 'MINT': 'EpBksLwPFdf7SLcQ2oNh1HsNWfMudrTVvSbpAdMRXaUh', 'TOTAL_ADDED_LIQUIDITY': 4600552538943.01, 'TOTAL_REMOVED_LIQUIDITY': 870984.891, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 5282011.87699249, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1727253648, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1716744101, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 8.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 25.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 9.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 17.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0681507706247817, 'is_outlier_isolation_forest': -1}
# Index: 93228, Data: {'LIQUIDITY_POOL_ADDRESS': 'AqidfRD5hDgfJSm6S8CvRq2pLvomgym87bgiQXsVs17p', 'MINT': '3UKUk3QZFoi69mepEBoMERM4duSsgj3Xm97GVYixxG2p', 'TOTAL_ADDED_LIQUIDITY': 1.77410725578367e+16, 'TOTAL_REMOVED_LIQUIDITY': 1.68645876010712e+16, 'NUM_LIQUIDITY_ADDS': 8.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 1.051971918, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1704248244, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704163117, 'LAST_SWAP_TIMESTAMP_ts': 1708451811, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 17.0, 'LAST_SWAP_TIMESTAMP_day': 20.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 2.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06611445784424186, 'is_outlier_isolation_forest': -1}
# Index: 92245, Data: {'LIQUIDITY_POOL_ADDRESS': '8NrkeHEzMawZaEurxF4QFBxcQ7jUpyUbM8qPxGjCMUzq', 'MINT': '94sFWT94hg6qK9VtYwGz8VxbyEMaXf9H2U3HTTbofimy', 'TOTAL_ADDED_LIQUIDITY': 63170513479833.3, 'TOTAL_REMOVED_LIQUIDITY': 40865722366169.7, 'NUM_LIQUIDITY_ADDS': 1042.0, 'NUM_LIQUIDITY_REMOVES': 6393.0, 'ADD_TO_REMOVE_RATIO': 1.545806848, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1729593956, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704314894, 'LAST_SWAP_TIMESTAMP_ts': 1729632360, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 10.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 22.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 20.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 21.0, 'LAST_SWAP_TIMESTAMP_day': 22.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0656779776827765, 'is_outlier_isolation_forest': -1}
# Index: 91012, Data: {'LIQUIDITY_POOL_ADDRESS': 'ANiG8Td1Xx4Te5VQTu7riMv5RnNoZjiWABBrzSzPKBKM', 'MINT': '3HoRVw2NyBLoLve19oKLxydwNEEkwX51kLGLskRZPm6Q', 'TOTAL_ADDED_LIQUIDITY': 108635292372596.0, 'TOTAL_REMOVED_LIQUIDITY': 108852958694430.0, 'NUM_LIQUIDITY_ADDS': 8.0, 'NUM_LIQUIDITY_REMOVES': 64.0, 'ADD_TO_REMOVE_RATIO': 0.9980003638, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1708333192, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704637646, 'LAST_SWAP_TIMESTAMP_ts': 1705215966, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 8.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 14.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 7.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 7.0, 'LAST_SWAP_TIMESTAMP_day': 14.0, 'LAST_SWAP_TIMESTAMP_weekday': 6.0, 'LAST_SWAP_TIMESTAMP_month': 1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06337977676650419, 'is_outlier_isolation_forest': -1}
# Index: 95256, Data: {'LIQUIDITY_POOL_ADDRESS': '3ne4mWqdYuNiYrYZC9TrA3FcfuFdErghH97vNPbjicr1', 'MINT': 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263', 'TOTAL_ADDED_LIQUIDITY': 2287393143117.23, 'TOTAL_REMOVED_LIQUIDITY': 2847503355904.54, 'NUM_LIQUIDITY_ADDS': 186415.0, 'NUM_LIQUIDITY_REMOVES': 87226.0, 'ADD_TO_REMOVE_RATIO': 0.8032977866, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1730418928, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704067581, 'LAST_SWAP_TIMESTAMP_ts': 1730419136, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 31.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 31.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': True, 'INACTIVITY_STATUS_Inactive': False, 'anomaly_score_isolation_forest': -0.06275449648677345, 'is_outlier_isolation_forest': -1}
# Index: 85149, Data: {'LIQUIDITY_POOL_ADDRESS': '2NbYW9NUVufMHKnuCM1mpmeTysHEGAcHq3EDL85kqi8w', 'MINT': '5ovWbyonBsts6kWsS49v5H3aDL61u8ahGGCSiWJhdoLp', 'TOTAL_ADDED_LIQUIDITY': 3607843703705510.0, 'TOTAL_REMOVED_LIQUIDITY': 1257636386632490.0, 'NUM_LIQUIDITY_ADDS': 6.0, 'NUM_LIQUIDITY_REMOVES': 8.0, 'ADD_TO_REMOVE_RATIO': 2.868749459, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706296585, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706293891, 'LAST_SWAP_TIMESTAMP_ts': 1712101672, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 18.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 2.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 4.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06211414759174605, 'is_outlier_isolation_forest': -1}
# Index: 91241, Data: {'LIQUIDITY_POOL_ADDRESS': 'B22H1ohpYuAGgb6Tuzx2uzTcYBZAv7FxCDknh1bPXwWr', 'MINT': '3HoRVw2NyBLoLve19oKLxydwNEEkwX51kLGLskRZPm6Q', 'TOTAL_ADDED_LIQUIDITY': 29696125334091.4, 'TOTAL_REMOVED_LIQUIDITY': 22075031033158.0, 'NUM_LIQUIDITY_ADDS': 10.0, 'NUM_LIQUIDITY_REMOVES': 26.0, 'ADD_TO_REMOVE_RATIO': 1.34523595, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1705254338, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704568628, 'LAST_SWAP_TIMESTAMP_ts': 1705215966, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 17.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 7.0, 'LAST_SWAP_TIMESTAMP_day': 14.0, 'LAST_SWAP_TIMESTAMP_weekday': 6.0, 'LAST_SWAP_TIMESTAMP_month': 1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.0619724434847897, 'is_outlier_isolation_forest': -1}
# Index: 93410, Data: {'LIQUIDITY_POOL_ADDRESS': '31vB5LKthALFAHMJRjmNsSLhKLdmosn2gmxzgMKt8sVa', 'MINT': 'EBSKyU6vx9X6WKSfmPxbsU4RJKUt8bm3aYrUs74feg9A', 'TOTAL_ADDED_LIQUIDITY': 1027304063856500.0, 'TOTAL_REMOVED_LIQUIDITY': 3004526297640370.0, 'NUM_LIQUIDITY_ADDS': 128.0, 'NUM_LIQUIDITY_REMOVES': 69.0, 'ADD_TO_REMOVE_RATIO': 0.3419188125, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1724986004, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704148264, 'LAST_SWAP_TIMESTAMP_ts': 1729830060, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 2.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 30.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 8.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 4.0, 'LAST_SWAP_TIMESTAMP_day': 25.0, 'LAST_SWAP_TIMESTAMP_weekday': 4.0, 'LAST_SWAP_TIMESTAMP_month': 10.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06140887564622177, 'is_outlier_isolation_forest': -1}
# Index: 85131, Data: {'LIQUIDITY_POOL_ADDRESS': 'EgCwqWCXVzETY2zEUffn7ZaCbyBtsHCzfYfZBBd5igkn', 'MINT': '5ovWbyonBsts6kWsS49v5H3aDL61u8ahGGCSiWJhdoLp', 'TOTAL_ADDED_LIQUIDITY': 3418771220095670.0, 'TOTAL_REMOVED_LIQUIDITY': 1768401799313.26, 'NUM_LIQUIDITY_ADDS': 8.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 1933.254773561, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706392536, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706297205, 'LAST_SWAP_TIMESTAMP_ts': 1712101672, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 21.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 27.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 5.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 23.0, 'LAST_SWAP_TIMESTAMP_day': 2.0, 'LAST_SWAP_TIMESTAMP_weekday': 1.0, 'LAST_SWAP_TIMESTAMP_month': 4.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.06108223935593016, 'is_outlier_isolation_forest': -1}
# Index: 86373, Data: {'LIQUIDITY_POOL_ADDRESS': '2qS6boYsGJbTSa7ruBR11BqvASNjHmR94ESmfADSTgDz', 'MINT': 'mZxEpyQiK6CXEfshR7F4gZ4U8yLpQdBuA3x7nJPvw6b', 'TOTAL_ADDED_LIQUIDITY': 345315486136837.0, 'TOTAL_REMOVED_LIQUIDITY': 735382501520734.0, 'NUM_LIQUIDITY_ADDS': 232.0, 'NUM_LIQUIDITY_REMOVES': 122.0, 'ADD_TO_REMOVE_RATIO': 0.4695726175, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1722540514, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1705941692, 'LAST_SWAP_TIMESTAMP_ts': 1723981385, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 19.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 8.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 16.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 22.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 11.0, 'LAST_SWAP_TIMESTAMP_day': 18.0, 'LAST_SWAP_TIMESTAMP_weekday': 6.0, 'LAST_SWAP_TIMESTAMP_month': 8.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05904587127261496, 'is_outlier_isolation_forest': -1}
# Index: 84580, Data: {'LIQUIDITY_POOL_ADDRESS': 'E5yLGHhe8PxughUVLRvFsc9ufcWviGRczW92moTGmzLJ', 'MINT': 'F2wSK4m7jirMsBSJCrgct2iSU3BnGjGzbk7bs1X8QutG', 'TOTAL_ADDED_LIQUIDITY': 1000001655971.15, 'TOTAL_REMOVED_LIQUIDITY': 1000001655971.15, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706447191, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706445104, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 13.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 12.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05771339228939354, 'is_outlier_isolation_forest': -1}
# Index: 57482, Data: {'LIQUIDITY_POOL_ADDRESS': '32PwVaakVBTYQswpB5nms1gmLdLd96CpwYrLmkgW6HQT', 'MINT': '89pyXij8KaMLJ7bQ17pJvNcPJp31McVc2bgwpDfHx4on', 'TOTAL_ADDED_LIQUIDITY': 1508717565.37719, 'TOTAL_REMOVED_LIQUIDITY': 13.695245827, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 110163598.699541, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728869799, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1715145825, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 8.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05753329235325999, 'is_outlier_isolation_forest': -1}
# Index: 53783, Data: {'LIQUIDITY_POOL_ADDRESS': '6dPCGvFsRaaPEeQ4BSWDScrMGToW7caDweHxxMyZ92Tf', 'MINT': '8ycCtaGR6K4rKzh21XKdK3caee22vqUB5Q1Hm714FHY3', 'TOTAL_ADDED_LIQUIDITY': 198734917332342.0, 'TOTAL_REMOVED_LIQUIDITY': 198593666158234.0, 'NUM_LIQUIDITY_ADDS': 22.0, 'NUM_LIQUIDITY_REMOVES': 20.0, 'ADD_TO_REMOVE_RATIO': 1.000711257, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1716764450, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1716106563, 'LAST_SWAP_TIMESTAMP_ts': 1716120089, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 26.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 8.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 19.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': 12.0, 'LAST_SWAP_TIMESTAMP_day': 19.0, 'LAST_SWAP_TIMESTAMP_weekday': 6.0, 'LAST_SWAP_TIMESTAMP_month': 5.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05722595892126714, 'is_outlier_isolation_forest': -1}
# Index: 88460, Data: {'LIQUIDITY_POOL_ADDRESS': '46ouBTFBSxCJoiuLMJ4uawdUaPi7Bi1xfVrajF9FERzZ', 'MINT': '8HZpZZQx2grB9y9U1zjwhyASmhn2FY4N1hoGnrToDMML', 'TOTAL_ADDED_LIQUIDITY': 10256437627725.5, 'TOTAL_REMOVED_LIQUIDITY': 8238106838595.46, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 4.0, 'ADD_TO_REMOVE_RATIO': 1.244999346, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1705361293, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1705360745, 'LAST_SWAP_TIMESTAMP_ts': 1707108041, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 15.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 15.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 4.0, 'LAST_SWAP_TIMESTAMP_day': 5.0, 'LAST_SWAP_TIMESTAMP_weekday': 0.0, 'LAST_SWAP_TIMESTAMP_month': 2.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05640029076541253, 'is_outlier_isolation_forest': -1}
# Index: 90963, Data: {'LIQUIDITY_POOL_ADDRESS': '8LeuBn515kSAQckUFHWvLL5AFBKkzXAQFg1aGHD59ZNw', 'MINT': 'AZR96E1fvEdZodnsLgQdsC6cVqUzDScox28NwZZuQXeJ', 'TOTAL_ADDED_LIQUIDITY': 14000000000000.0, 'TOTAL_REMOVED_LIQUIDITY': 1164833982309440.0, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 0.01201888013, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1704660303, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704643907, 'LAST_SWAP_TIMESTAMP_ts': 1704645034, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 20.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 7.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 16.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 7.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 16.0, 'LAST_SWAP_TIMESTAMP_day': 7.0, 'LAST_SWAP_TIMESTAMP_weekday': 6.0, 'LAST_SWAP_TIMESTAMP_month': 1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.056243010039124464, 'is_outlier_isolation_forest': -1}
# Index: 84726, Data: {'LIQUIDITY_POOL_ADDRESS': 'BmHuXoh9xG1FxK3GFqDAaamv5vnvXpEHzS1odccpMgGL', 'MINT': '52QaBoDMTKTZBoGT7jZgpjpHJq5v4r1mEPH641q8V1Zg', 'TOTAL_ADDED_LIQUIDITY': 129871219592.476, 'TOTAL_REMOVED_LIQUIDITY': 129871219592.476, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706401947, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1706401087, 'LAST_SWAP_TIMESTAMP_ts': -9223372037, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 28.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': -1.0, 'LAST_SWAP_TIMESTAMP_day': -1.0, 'LAST_SWAP_TIMESTAMP_weekday': -1.0, 'LAST_SWAP_TIMESTAMP_month': -1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05574063193102907, 'is_outlier_isolation_forest': -1}
# Index: 48634, Data: {'LIQUIDITY_POOL_ADDRESS': 'BSUqv4QDuFK2MfmqerZw69KeeFEYww6LYQEwSYEukLeN', 'MINT': '9wpW1hrB3WX5A8Hfpf3VitoN2CyafABYDZMHgU1eLBfs', 'TOTAL_ADDED_LIQUIDITY': 329890223542.61, 'TOTAL_REMOVED_LIQUIDITY': 36748.786942, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 8976901.03521703, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728870707, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1717314994, 'LAST_SWAP_TIMESTAMP_ts': 1717880108, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 7.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 2.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 6.0, 'LAST_SWAP_TIMESTAMP_hour': 20.0, 'LAST_SWAP_TIMESTAMP_day': 8.0, 'LAST_SWAP_TIMESTAMP_weekday': 5.0, 'LAST_SWAP_TIMESTAMP_month': 6.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05557321718920605, 'is_outlier_isolation_forest': -1}
# Index: 50982, Data: {'LIQUIDITY_POOL_ADDRESS': '51GLh7Z2whymNkpBy4HnschqRMjR2KsvrJ1jwMcE1inj', 'MINT': 'H9YtnULnyHMPiAkD5tFwCpB3sDtmNUdi8cGuTkMYvtXm', 'TOTAL_ADDED_LIQUIDITY': 384439153922.226, 'TOTAL_REMOVED_LIQUIDITY': 39191.100013, 'NUM_LIQUIDITY_ADDS': 2.0, 'NUM_LIQUIDITY_REMOVES': 1.0, 'ADD_TO_REMOVE_RATIO': 9809348.39273979, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1728870164, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1716807031, 'LAST_SWAP_TIMESTAMP_ts': 1716826848, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 1.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 14.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 10.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 27.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 5.0, 'LAST_SWAP_TIMESTAMP_hour': 16.0, 'LAST_SWAP_TIMESTAMP_day': 27.0, 'LAST_SWAP_TIMESTAMP_weekday': 0.0, 'LAST_SWAP_TIMESTAMP_month': 5.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05557079350355554, 'is_outlier_isolation_forest': -1}
# Index: 91767, Data: {'LIQUIDITY_POOL_ADDRESS': '9tt7WY2ouxx1QPfzXw1K9hPhJ2QEJBfmvmuh4HbV1MvE', 'MINT': 'BY8gwpdoS8sLWTQAmxz4P7wjSHZmBSptDXDMgWFSDVDa', 'TOTAL_ADDED_LIQUIDITY': 20143080326861.1, 'TOTAL_REMOVED_LIQUIDITY': 18721509247452.8, 'NUM_LIQUIDITY_ADDS': 4.0, 'NUM_LIQUIDITY_REMOVES': 72.0, 'ADD_TO_REMOVE_RATIO': 1.075932504, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1706499752, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1704411574, 'LAST_SWAP_TIMESTAMP_ts': 1706217981, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 3.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 29.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 23.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 4.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 1.0, 'LAST_SWAP_TIMESTAMP_hour': 21.0, 'LAST_SWAP_TIMESTAMP_day': 25.0, 'LAST_SWAP_TIMESTAMP_weekday': 3.0, 'LAST_SWAP_TIMESTAMP_month': 1.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05459779269517406, 'is_outlier_isolation_forest': -1}
# Index: 71695, Data: {'LIQUIDITY_POOL_ADDRESS': '7VRcBKJWSZPkF1nPJZhGqEYDMSZUrnkK8CgHVnPbeX9Y', 'MINT': '5dxxBvWyqBd5BNYqxRiuKcHs52Sqtwy9TTAq5zJ9KPpD', 'TOTAL_ADDED_LIQUIDITY': 50000000000000.0, 'TOTAL_REMOVED_LIQUIDITY': 94795767892210.0, 'NUM_LIQUIDITY_ADDS': 1.0, 'NUM_LIQUIDITY_REMOVES': 2.0, 'ADD_TO_REMOVE_RATIO': 0.527449707, 'LAST_POOL_ACTIVITY_TIMESTAMP_ts': 1710761345, 'FIRST_POOL_ACTIVITY_TIMESTAMP_ts': 1710711483, 'LAST_SWAP_TIMESTAMP_ts': 1710737577, 'LAST_POOL_ACTIVITY_TIMESTAMP_hour': 11.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_day': 18.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_weekday': 0.0, 'LAST_POOL_ACTIVITY_TIMESTAMP_month': 3.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_hour': 21.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_day': 17.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_weekday': 6.0, 'FIRST_POOL_ACTIVITY_TIMESTAMP_month': 3.0, 'LAST_SWAP_TIMESTAMP_hour': 4.0, 'LAST_SWAP_TIMESTAMP_day': 18.0, 'LAST_SWAP_TIMESTAMP_weekday': 0.0, 'LAST_SWAP_TIMESTAMP_month': 3.0, 'INACTIVITY_STATUS_Active': False, 'INACTIVITY_STATUS_Inactive': True, 'anomaly_score_isolation_forest': -0.05442392840968746, 'is_outlier_isolation_forest': -1}

# %%
subset_to_label.to_csv('/kaggle/working/subset_to_label.csv', index=False)
